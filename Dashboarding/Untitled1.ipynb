# %%
import pandas as pd

# %%
df=pd.read_csv('df_PWCO.csv')

# %%
df.head()
# Out:
#               Breakdown       ttm 12/30/2020 12/30/2019 12/30/2018 12/30/2017  \
# 0         Total Revenue     86.07    189.965    757.639      1,110    955.938
# 1     Operating Expense   217.999    302.021      1,207      1,438      1,629
# 2      Operating Income  -131.929   -112.056   -449.421    -328.28   -673.308
# 3  Other Income Expense         -          -          -          -    -20.307
# 4         Pretax Income  -131.929   -112.056   -449.421    -328.28   -693.615
#
#             finStat group_name
# 0  income statement       PWCO
# 1  income statement       PWCO
# 2  income statement       PWCO
# 3  income statement       PWCO
# 4  income statement       PWCO

# %%
# Sector(s): Technology
# Industry: Consumer Electronics
# Full Time Employees: 147,000
df['sector']=' Utilities'

# %%
df.head()
# Out:
#            Breakdown        ttm 12/30/2020 12/30/2019 12/30/2018 12/30/2017  \
# 0      Total Revenue  2,657,100  2,632,900  2,991,900  2,836,100  2,841,100
# 1    Cost of Revenue  2,060,500  2,054,100  2,321,700  2,183,700  2,138,100
# 2       Gross Profit    596,600    578,800    670,200    652,400    703,000
# 3  Operating Expense    479,800    535,600    576,300    546,300    525,500
# 4   Operating Income    116,800     43,200     93,900    106,100    177,500
#
#             finStat    group_name       sector
# 0  income statement  Tarkett S.A.  Industrials
# 1  income statement  Tarkett S.A.  Industrials
# 2  income statement  Tarkett S.A.  Industrials
# 3  income statement  Tarkett S.A.  Industrials
# 4  income statement  Tarkett S.A.  Industrials

# %%
df.to_csv ('df_TARKETT.csv', index = False, header=True)
