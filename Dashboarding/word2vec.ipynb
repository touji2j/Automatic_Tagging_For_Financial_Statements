# %%
#Import all the dependencies
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
data = ["I love machine learning. Its awesome.",
        "I love coding in python",
        "I love building chatbots",
        "they chat amagingly well"]

tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(L2)]

# %%
# tagged_data

# %%
max_epochs = 100
vec_size = 20
alpha = 0.025

model = Doc2Vec(size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("d2v.model")
print("Model Saved")
# Out:
# D:\anaconda\lib\site-packages\gensim\models\doc2vec.py:319: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# iteration 0
# <ipython-input-12-f2c2304d9f55>:17: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   epochs=model.iter)
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# ...

# %%
from gensim.models.doc2vec import Doc2Vec
model= Doc2Vec.load("d2v.model")

# %%
model= Doc2Vec.load("d2v.model")

# %%
#to find the vector of a document which is not in training data
test_data = word_tokenize("Gross Profit".lower())

# %%
v1 = model.infer_vector(test_data)
print("V1_infer", v1)
# Out:
# V1_infer [ 0.10029745 -0.0176486  -0.00469228  0.03150669 -0.02422978  0.0090353
#   0.03236697 -0.04767675  0.02901927 -0.06061406 -0.01940673  0.07376882
#  -0.02965959 -0.07009745  0.03129087 -0.00349004 -0.04965414 -0.02073497
#  -0.06359408 -0.05188288]

# %%
# to find most similar doc using tags
similar_doc = model.docvecs.most_similar('1')
print(similar_doc)
# Out:
# [('91', 0.9474658966064453), ('1459', 0.8003714084625244), ('1460', 0.7872531414031982), ('4504', 0.7871924638748169), ('3818', 0.777490496635437), ('1843', 0.7616356611251831), ('4376', 0.7508925199508667), ('2928', 0.7449877262115479), ('4895', 0.7146762609481812), ('4897', 0.7119969129562378)]

# %%
print(model.docvecs['0'])
# Out:
# [ 0.41887546 -2.340429    2.7453468  -0.82578987 -0.36925107  0.23534289
#  -0.6064339  -1.7472445   1.0107558   0.76149625  0.03465255  0.996986
#  -1.218872   -2.0855567   2.670275   -0.57792443 -0.11848154 -1.039815
#   0.61139506 -1.8475794 ]

# %%
dfs.head()
# Out:
#                  elt          ttm    9/29/2020    9/29/2019    9/29/2018  \
# 0      Total Revenue  347,155,000  274,515,000  260,174,000  265,595,000
# 1    Cost of Revenue  204,804,000  169,559,000  161,782,000  163,756,000
# 2       Gross Profit  142,351,000  104,956,000   98,392,000  101,839,000
# 3  Operating Expense   42,413,000   38,668,000   34,462,000   30,941,000
# 4   Operating Income   99,938,000   66,288,000   63,930,000   70,898,000
#
#      9/29/2017           finStat group_name      sector 12/30/2020 12/30/2019  \
# 0  229,234,000  income statement      Apple  Technology        NaN        NaN
# 1  141,048,000  income statement      Apple  Technology        NaN        NaN
# 2   88,186,000  income statement      Apple  Technology        NaN        NaN
# 3   26,842,000  income statement      Apple  Technology        NaN        NaN
# 4   61,344,000  income statement      Apple  Technology        NaN        NaN
#
#   12/30/2018 12/30/2017
# 0        NaN        NaN
# ...

# %%
# B=[]
# for i in range(len(L1)):
#     B.append(word_tokenize(L1[i].lower()))

# %%
# V=[]
# for i in range(len(B)):
#     V.append(model.infer_vector(B[i]))

# %%
# d = {'elt':L1,'vec':V}
# df1=pd.DataFrame(d)
# df1.head()

# %%
# dff=pd.merge(dfs, df1, on='elt', how='left')
# dff.head(40)

# %%
from gensim.models.doc2vec import Doc2Vec
model= Doc2Vec.load("d2v.model")

# %%
def return_label(A):
    tokens = A.split()
    new_vector = model.infer_vector(tokens)
    sims = model.docvecs.most_similar([new_vector])
    Top10=[]
    for i in range(10):
        Top10.append(list(df_tag['IFRS_tag'])[int(sims[i][0])])

    return Top10

# %%
return_label('Cost Of Sales')
# Out:
# ['ifrs-full_UsefulLifeMeasuredAsPeriodOfTimePropertyPlantAndEquipment_label',
#  'ifrs-full_UsefulLifeMeasuredInProductionOrOtherSimilarUnitsPropertyPlantAndEquipment_label',
#  'ifrs-full_UsefulLifeMeasuredAsPeriodOfTimeInvestmentPropertyCostModel_label',
#  'ifrs-full_UsefulLifeMeasuredAsPeriodOfTimeIntangibleAssetsOtherThanGoodwill_label',
#  'ifrs-full_InputToMethodUsedToMeasureContractsWithinScopeOfIFRS17_label',
#  'ifrs-full_UsefulLifeMeasuredAsPeriodOfTimeBiologicalAssetsAtCost_label',
#  'ifrs-full_PurchasesOfPropertyAndOtherAssetsRelatedPartyTransactions_label',
#  'ifrs-full_SalesOfPropertyAndOtherAssetsRelatedPartyTransactions_label',
#  'ifrs-full_DateAsAtWhichEntityPlansToApplyNewIFRSInitially_label',
#  'ifrs-full_Merchandise_label']

# %%
dfs['Top10_affected']=""
for i in range(len(dfs)):
    dfs['Top10_affected'][i]=return_label(dfs['elt'][i])

# %%
dfs.head(39)
# Out:
#                                                   elt          ttm  \
# 0                                       Total Revenue  347,155,000
# 1                                     Cost of Revenue  204,804,000
# 2                                        Gross Profit  142,351,000
# 3                                   Operating Expense   42,413,000
# 4                                    Operating Income   99,938,000
# 5           Net Non Operating Interest Income Expense      345,000
# 6                                Other Income Expense      577,000
# 7                                       Pretax Income  100,860,000
# 8                                       Tax Provision   14,058,000
# 9                      Net Income Common Stockholders   86,802,000
# 10           Diluted NI Available to Com Stockholders   86,802,000
# 11                                          Basic EPS            -
# 12                                        Diluted EPS            -
# ...

# %%
Top10=[]
for i in range(10):
    Top10.append(L2[int(sims[i][0])])
Top10
# Out:
# ['Circulation revenue',
#  'Dividends received',
#  'Dividends received',
#  'Dividends received',
#  'Revenue from rendering of internet and data services',
#  'Revenue',
#  'Proceeds from exercise of warrants',
#  'Cancellation of treasury shares',
#  'Revenue from sale of books',
#  'Revenue from sale of gold']

# %%
L2
# Out:
# ['Accounting profit',
#  'Accumulated increase (decrease) in fair value of financial liability, attributable to changes in credit risk of liability',
#  'Accumulated increase (decrease) in fair value of loan or receivable, attributable to changes in credit risk of financial assets',
#  'Acquisitions through business combinations, biological assets',
#  'Acquisitions through business combinations, intangible assets other than goodwill',
#  'Acquisitions through business combinations, investment property',
#  'Acquisitions through business combinations, other provisions',
#  'Acquisitions through business combinations, property, plant and equipment',
#  'Actuarial assumption of discount rates',
#  'Actuarial assumption of expected rates of salary increases',
#  'Actuarial assumption of medical cost trend rates',
#  'Additional information about entity exposure to risk',
#  'Additional information [abstract]',
#  'Additional provisions, other provisions',
# ...
