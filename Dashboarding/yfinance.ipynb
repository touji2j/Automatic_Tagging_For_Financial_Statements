# %%
import yfinance as yf
import pandas as pd
from bs4 import BeautifulSoup
import re
from selenium import webdriver
import chromedriver_binary
import string
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# #### 1. Choose company ✨

# %%
is_link = 'https://finance.yahoo.com/quote/XPEV/financials?p=XPEV'

# %%
driver = webdriver.Chrome(executable_path=r'D:/chromedriver_win32/chromedriver.exe')

# %%
driver.get(is_link)
html = driver.execute_script('return document.body.innerHTML;')
soup = BeautifulSoup(html,'lxml')

# %%
features = soup.find_all('div', class_='D(tbr)')

# %%
headers = []
temp_list = []
label_list = []
final = []
index = 0
#create headers
for item in features[0].find_all('div', class_='D(ib)'):
    headers.append(item.text)
#statement contents
while index <= len(features)-1:
    #filter for each line of the statement
    temp = features[index].find_all('div', class_='D(tbc)')
    for line in temp:
        #each item adding to a temporary list
        temp_list.append(line.text)
    #temp_list added to final list
    final.append(temp_list)
    #clear temp_list
    temp_list = []
    index+=1
df = pd.DataFrame(final[1:])
df.columns = headers

# %% [markdown]
# #### 2. Personalize Data ✨

# %%
df['finStat']='income statement'
df['group_name']='XPeng Inc.'
df['sector']='Consumer Cyclical'
df.head(59)
# Out:
#                                             Breakdown         ttm  12/30/2020  \
# 0                                       Total Revenue   8,383,178   5,844,321
# 1                                     Cost of Revenue   7,767,475   5,578,332
# 2                                        Gross Profit     615,703     265,989
# 3                                   Operating Expense   5,164,089   4,559,725
# 4                                    Operating Income  -4,548,386  -4,293,736
# 5           Net Non Operating Interest Income Expense     242,165     110,585
# 6                                Other Income Expense   1,438,659   1,452,389
# 7                                       Pretax Income  -2,867,562  -2,730,762
# 8                                       Tax Provision       1,223       1,223
# 9                      Net Income Common Stockholders  -4,741,236  -4,889,729
# 10           Diluted NI Available to Com Stockholders  -4,741,236  -4,889,729
# 11                                          Basic EPS           -      -12.96
# 12                                        Diluted EPS           -      -12.96
# 13                               Basic Average Shares           -     377,135
# 14                             Diluted Average Shares           -     377,135
# 15                 Total Operating Income as Reported  -4,548,386  -4,293,736
# 16                                     Total Expenses  12,931,564  10,138,057
# 17  Net Income from Continuing & Discontinued Oper...  -2,868,785  -2,731,985
# 18                                  Normalized Income  -3,687,896  -3,753,504
# 19                                    Interest Income     257,480     133,036
# 20                                   Interest Expense      15,315      22,451
# 21                                Net Interest Income     242,165     110,585
# 22                                               EBIT  -2,852,247  -2,708,311
# 23                                             EBITDA  -2,852,247           -
# 24                         Reconciled Cost of Revenue   7,767,475   5,578,332
# 25                            Reconciled Depreciation           -     437,939
# 26  Net Income from Continuing Operation Net Minor...  -2,868,785  -2,731,985
# 27             Total Unusual Items Excluding Goodwill   1,365,185   1,362,025
# 28                                Total Unusual Items   1,365,185   1,362,025
# 29                                  Normalized EBITDA  -4,217,432  -3,632,397
# 30                                 Tax Rate for Calcs           0           0
# 31                        Tax Effect of Unusual Items     546,074     340,506
#
#     12/30/2019  12/30/2018           finStat  group_name             sector
# 0    2,321,219       9,706  income statement  XPeng Inc.  Consumer Cyclical
# 1    2,879,360      12,067  income statement  XPeng Inc.  Consumer Cyclical
# 2     -558,141      -2,361  income statement  XPeng Inc.  Consumer Cyclical
# 3    3,222,433   1,692,273  income statement  XPeng Inc.  Consumer Cyclical
# 4   -3,780,574  -1,694,634  income statement  XPeng Inc.  Consumer Cyclical
# 5       56,826      59,554  income statement  XPeng Inc.  Consumer Cyclical
# 6       32,076     236,257  income statement  XPeng Inc.  Consumer Cyclical
# 7   -3,691,672  -1,398,823  income statement  XPeng Inc.  Consumer Cyclical
# 8            1           0  income statement  XPeng Inc.  Consumer Cyclical
# 9   -3,719,352  -2,254,864  income statement  XPeng Inc.  Consumer Cyclical
# 10  -3,719,352  -2,254,864  income statement  XPeng Inc.  Consumer Cyclical
# 11       -8.76       -2.84  income statement  XPeng Inc.  Consumer Cyclical
# 12       -8.76       -2.84  income statement  XPeng Inc.  Consumer Cyclical
# 13     424,755     793,359  income statement  XPeng Inc.  Consumer Cyclical
# 14     424,755     793,359  income statement  XPeng Inc.  Consumer Cyclical
# 15  -3,780,574  -1,694,634  income statement  XPeng Inc.  Consumer Cyclical
# 16   6,101,793   1,704,340  income statement  XPeng Inc.  Consumer Cyclical
# 17  -3,691,673  -1,398,823  income statement  XPeng Inc.  Consumer Cyclical
# 18  -3,712,432  -1,653,184  income statement  XPeng Inc.  Consumer Cyclical
# 19      88,843      65,376  income statement  XPeng Inc.  Consumer Cyclical
# 20      32,017       5,822  income statement  XPeng Inc.  Consumer Cyclical
# 21      56,826      59,554  income statement  XPeng Inc.  Consumer Cyclical
# 22  -3,659,655  -1,393,001  income statement  XPeng Inc.  Consumer Cyclical
# 23           -           -  income statement  XPeng Inc.  Consumer Cyclical
# 24   2,879,360      12,067  income statement  XPeng Inc.  Consumer Cyclical
# 25     226,665      95,631  income statement  XPeng Inc.  Consumer Cyclical
# 26  -3,691,673  -1,398,823  income statement  XPeng Inc.  Consumer Cyclical
# 27      27,679     254,361  income statement  XPeng Inc.  Consumer Cyclical
# 28      27,679     254,361  income statement  XPeng Inc.  Consumer Cyclical
# 29  -3,460,669  -1,551,731  income statement  XPeng Inc.  Consumer Cyclical
# 30           0           0  income statement  XPeng Inc.  Consumer Cyclical
# 31       6,920           0  income statement  XPeng Inc.  Consumer Cyclical

# %% [markdown]
# #### 3. Save Data ✨

# %%
df.to_csv ('df_XPeng.csv', index = False, header=True)
